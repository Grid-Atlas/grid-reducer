# %% [markdown]
# 📘 Jupyter Notebook: Visualizing and Comparing Power System Graphs with GeoPandas

# %%
# 📦 Section 1: Imports & Setup
from pathlib import Path
import geopandas as gpd
import pandas as pd
from grid_reducer.utils import get_ckt_from_opendss_model
from grid_reducer.network import get_graph_from_circuit
from grid_reducer.plot import graph_to_geodataframe
from grid_reducer.reducer import OpenDSSModelReducer

# %%
# ⚡ Section 2: Load and Parse OpenDSS Circuit

# Specify the path to your DSS master file
master_dss_path = Path("../tests/data/smartds/Master.dss")

# Load the circuit object from the OpenDSS model
ckt = get_ckt_from_opendss_model(master_dss_path)
reducer = OpenDSSModelReducer(master_dss_file=master_dss_path)
reduced_ckt = reducer.reduce()

# Create a NetworkX graph from the circuit
#graph = get_graph_from_circuit(ckt)
graph = get_graph_from_circuit(reduced_ckt)

# Print basic info
print(f"Number of nodes: {len(graph.nodes)}")
print(f"Number of edges: {len(graph.edges)}")
# Out:
# Number of aggregated lines = 12
# Number of removed lines = 24
# Switch buses: set()
# Transforming coordinates...
# {'p12udt1266-p12uhs0_1247x': array([-0.47362126,  0.23428641]), 'p12udt2952': array([-0.40612729,  0.1544501 ]), 'p12udt2953': array([-0.40286351,  0.18664116]), 'p12udt2952-p12udt5990xx': array([-0.41769873,  0.12434794]), 'p12udt2655-p12udt2659x': array([-0.62087473, -0.39655792]), 'p12udt2659': array([-0.64385377, -0.41892187]), 'p12udt5620': array([-0.59215917, -0.51739021]), 'p12udt6806': array([-0.60667483, -0.54508443]), 'p12udt2644-p12udt5620x': array([-0.57831408, -0.48833597]), 'p12udt2661': array([-0.55716346, -0.42465526]), 'p12udt2644': array([-0.56609067, -0.45754336]), 'p12udt2654-p12udt2661x': array([-0.55472764, -0.38989995]), 'p12udt2651-p12udt2658x': array([-0.59493188, -0.32289606]), 'p12udt2658': array([-0.62417545, -0.33180642]), 'p12udt2950-p12udt2954xx': array([-0.94204558, -0.24861081]), 'p12udt2950-p12udt2954x': array([-0.97125992, -0.25672032]), 'p12udt2951-p12udt2954x': array([-0.81774771, -0.22853247]), 'p12udt2951-p12udt2954xx': array([-0.850235  , -0.22991317]), 'p12udt2951-p12udt2954xxx': array([-0.88170905, -0.23456003]), 'p12udt2955': array([-0.75394226, -0.24892889]), 'p12udt2951': array([-0.78471567, -0.23308076]), 'p12udt5935': array([-0.7822989 , -0.30923233]), 'p12udt5933': array([-0.80102218, -0.33525831]), 'p12udt2955-p12udt5935x': array([-0.76544409, -0.28087413]), 'p12udt5438': array([-0.71983763, -0.24030231]), 'p12udt5438-p12udt6930x': array([-0.61380929, -0.23972784]), 'p12udt5438-p12udt6930x_b1_1': array([-0.64988941, -0.23598013]), 'p12udt4007-p12udt7454x': array([-0.52604175, -0.09019804]), 'p12udt4007': array([-0.55429198, -0.08069279]), 'p12udt1246-p12udt7454x': array([-0.47224213, -0.1095189 ]), 'p12udt7454': array([-0.49847333, -0.0995801 ]), 'p12udt1241-p12udt1242x': array([-0.27278276, -0
# 1        1      1      2       5.86  7.199558           Line   line__67
# 2        2      1      3       3.10  7.199558           Line  line__128
# 3        3      3    119       5.18  7.199558           Line   line__15
# 4        4      4    123       2.57  7.199558           Line   line__75
#
#                                             geometry
# 0     LINESTRING (-0.4939 0.24296, -0.48705 0.21228)
# 1       LINESTRING (-0.4038 0.1422, -0.4058 0.19496)
# 2      LINESTRING (-0.4038 0.1422, -0.40788 0.11458)
# 3    LINESTRING (-0.40788 0.11458, -0.45442 0.11173)
# 4  LINESTRING (-0.61119 -0.38761, -0.59003 -0.37822)

# %%
# 🧭 Section 4: Explore the Graph with Interactive Map

# Visualize with geopandas.explore()
gdf.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfb8b68f0a6e6d8708156ab3c9f81e85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfb8b68f0a6e6d8708156ab3c9f81e85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfb8b68f0a6e6d8708156ab3c9f81e85 = L.map(
#                 &quot;map_bfb8b68f0a6e6d8708156ab3c9f81e85&quot;,
#                 {
#                     center: [0.01929492260744886, -0.03688081416800537],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_bfb8b68f0a6e6d8708156ab3c9f81e85);
#
#
#
#
#
#             var tile_layer_0f26dea3da6cc6b8cec9a9a3eb07b6f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f26dea3da6cc6b8cec9a9a3eb07b6f6.addTo(map_bfb8b68f0a6e6d8708156ab3c9f81e85);
#
#
#             map_bfb8b68f0a6e6d8708156ab3c9f81e85.fitBounds(
#                 [[-0.7107402716931008, -1.003110182998718], [0.7493301169079986, 0.9293485546627072]],
#                 {}
#             );
#
#
#         function geo_json_06061eb09de34e1d296cada864faf4ef_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_06061eb09de34e1d296cada864faf4ef_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_06061eb09de34e1d296cada864faf4ef_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_06061eb09de34e1d296cada864faf4ef_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_06061eb09de34e1d296cada864faf4ef_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_06061eb09de34e1d296cada864faf4ef.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_06061eb09de34e1d296cada864faf4ef_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_06061eb09de34e1d296cada864faf4ef = L.geoJson(null, {
#                 onEachFeature: geo_json_06061eb09de34e1d296cada864faf4ef_onEachFeature,
#
#                 style: geo_json_06061eb09de34e1d296cada864faf4ef_styler,
#                 pointToLayer: geo_json_06061eb09de34e1d296cada864faf4ef_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_06061eb09de34e1d296cada864faf4ef_add (data) {
#             geo_json_06061eb09de34e1d296cada864faf4ef
#                 .addData(data);
#         }
#             geo_json_06061eb09de34e1d296cada864faf4ef_add({&quot;bbox&quot;: [-1.003110182998718, -0.7107402716931008, 0.9293485546627072, 0.7493301169079986], &quot;features&quot;: [{&quot;bbox&quot;: [-0.49389693345190744, 0.21227712177244007, -0.48705367057767984, 0.242961560070615], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.49389693345190744, 0.242961560070615], [-0.48705367057767984, 0.21227712177244007]], &q

# %%
# 🔍 Section 5: Comparing Multiple Graphs Side-by-Side

# Load a second circuit (e.g., a modified version for comparison)
master_dss_path2 = Path("../tests/data/smartds/Master.dss")
ckt2 = get_ckt_from_opendss_model(master_dss_path2)
reducer = OpenDSSModelReducer(master_dss_file=master_dss_path)
reduced_ckt = reducer.reduce()
ckt2 = reduced_ckt
graph2 = get_graph_from_circuit(ckt2)
gdf2 = graph_to_geodataframe(graph2)

# Add 'category' column to both
gdf["source"] = "Base"
gdf2["source"] = "Variant"

# Merge for comparison
combined_gdf = pd.concat([gdf, gdf2], ignore_index=True)

# Visualize both overlaid, color-coded by source
combined_gdf.explore(column="source", legend=True, cmap="Set2")
# Out:
# Number of aggregated lines = 12
# Number of removed lines = 24
# Transforming coordinates...
# {'p12udt1266-p12uhs0_1247x': array([-0.47362126,  0.23428641]), 'p12udt2952': array([-0.40612729,  0.1544501 ]), 'p12udt2953': array([-0.40286351,  0.18664116]), 'p12udt2952-p12udt5990xx': array([-0.41769873,  0.12434794]), 'p12udt2655-p12udt2659x': array([-0.62087473, -0.39655792]), 'p12udt2659': array([-0.64385377, -0.41892187]), 'p12udt5620': array([-0.59215917, -0.51739021]), 'p12udt6806': array([-0.60667483, -0.54508443]), 'p12udt2644-p12udt5620x': array([-0.57831408, -0.48833597]), 'p12udt2661': array([-0.55716346, -0.42465526]), 'p12udt2644': array([-0.56609067, -0.45754336]), 'p12udt2654-p12udt2661x': array([-0.55472764, -0.38989995]), 'p12udt2651-p12udt2658x': array([-0.59493188, -0.32289606]), 'p12udt2658': array([-0.62417545, -0.33180642]), 'p12udt2950-p12udt2954xx': array([-0.94204558, -0.24861081]), 'p12udt2950-p12udt2954x': array([-0.97125992, -0.25672032]), 'p12udt2951-p12udt2954x': array([-0.81774771, -0.22853247]), 'p12udt2951-p12udt2954xx': array([-0.850235  , -0.22991317]), 'p12udt2951-p12udt2954xxx': array([-0.88170905, -0.23456003]), 'p12udt2955': array([-0.75394226, -0.24892889]), 'p12udt2951': array([-0.78471567, -0.23308076]), 'p12udt5935': array([-0.7822989 , -0.30923233]), 'p12udt5933': array([-0.80102218, -0.33525831]), 'p12udt2955-p12udt5935x': array([-0.76544409, -0.28087413]), 'p12udt5438': array([-0.71983763, -0.24030231]), 'p12udt5438-p12udt6930x': array([-0.61380929, -0.23972784]), 'p12udt5438-p12udt6930x_b1_1': array([-0.64988941, -0.23598013]), 'p12udt4007-p12udt7454x': array([-0.52604175, -0.09019804]), 'p12udt4007': array([-0.55429198, -0.08069279]), 'p12udt1246-p12udt7454x': array([-0.47224213, -0.1095189 ]), 'p12udt7454': array([-0.49847333, -0.0995801 ]), 'p12udt1241-p12udt1242x': array([-0.27278276, -0.09234896]), 'p12udt1242': array([-0.2765315 , -0.12405911]), 'p12udt1243-p12udt7448x': array([-0.22916812, -0.09561754]), 'p12udt7448': array([-0.2293226, -0.1290471]), 'p12udt7463-p12udt7471x': array([-0.18564113, -0.09408921]), 'p12udt7471': array([-0.18207269, -0.12588346]), 'p12udt3325-p12udt3328x': array([ 0.06961365, -0.67120895]), 'p12udt3328': array([ 0.07109103, -0.70263681]), 'p12udt4010-p12udt4011x': array([ 0.11474217, -0.54752322]), 'p12udt4011': array([ 