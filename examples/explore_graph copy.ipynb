# %% [markdown]
# 📘 Jupyter Notebook: Visualizing and Comparing Power System Graphs with GeoPandas

# %%
# 📦 Section 1: Imports & Setup
from pathlib import Path
import geopandas as gpd
import pandas as pd
from grid_reducer.utils import get_ckt_from_opendss_model
from grid_reducer.network import get_graph_from_circuit
from grid_reducer.plot import graph_to_geodataframe
from grid_reducer.reducer import OpenDSSModelReducer

# %%
# ⚡ Section 2: Load and Parse OpenDSS Circuit

# Specify the path to your DSS master file
master_dss_path = Path("../tests/data/smartds/Master.dss")

# Load the circuit object from the OpenDSS model
ckt = get_ckt_from_opendss_model(master_dss_path)
reducer = OpenDSSModelReducer(master_dss_file=master_dss_path)
reduced_ckt1 = reducer.reduce(transform_coordinate=False, noise_level="none")
reduced_ckt2 = reducer.reduce(transform_coordinate=False, noise_level="low")
reduced_ckt3 = reducer.reduce(transform_coordinate=True, noise_level="none")
reduced_ckt4 = reducer.reduce(transform_coordinate=True, noise_level="low")

# Create a NetworkX graph from the circuit
#graph = get_graph_from_circuit(ckt)
graph1 = get_graph_from_circuit(reduced_ckt1)
graph2 = get_graph_from_circuit(reduced_ckt2)
graph3 = get_graph_from_circuit(reduced_ckt3)
graph4 = get_graph_from_circuit(reduced_ckt4)
graph5 = get_graph_from_circuit(ckt)

# Print basic info
#print(f"Number of nodes: {len(graph.nodes)}")
#print(f"Number of edges: {len(graph.edges)}")
# Out:
# Number of aggregated lines = 12
# Number of removed lines = 24
# Number of aggregated lines = 12
# Number of removed lines = 24
# Noise level:low; Noise scale: 0.01
# Number of aggregated lines = 12
# Number of removed lines = 24
# Transforming coordinates...
# Time: 2.3034918308258057
# Number of aggregated lines = 12
# Number of removed lines = 24
# Transforming coordinates...
# Time: 0.26082777976989746
# Noise level:low; Noise scale: 0.01

# %%
gdf1 = graph_to_geodataframe(graph1)
gdf2 = graph_to_geodataframe(graph2)
gdf3 = graph_to_geodataframe(graph3)
gdf4 = graph_to_geodataframe(graph4)
gdf5 = graph_to_geodataframe(graph5)

# %%
# transform_coordinate=False, noise_level="none"
gdf1.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.52  7.199558           Line  line__102
# 1        1      1      2       0.07  7.199558           Line   line__11
# 2        2      1      3       1.97  7.199558           Line  line__128
# 3        3      3    119       0.01  7.199558           Line   line__88
# 4        4      4    123       0.00  7.199558           Line   line__44
#
#                                             geometry
# 0  LINESTRING (-122.48087 38.2472, -122.48538 38....
# 1  LINESTRING (-122.51227 38.26007, -122.51293 38...
# 2  LINESTRING (-122.51227 38.26007, -122.5009 38....
# 3  LINESTRING (-122.5009 38.24649, -122.5009 38.2...
# 4  LINESTRING (-122.5391 38.2444, -122.53911 38.2...

# %%
# transform_coordinate=False, noise_level="low"
gdf2.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       2.12  7.199558           Line  line__102
# 1        1      1      2       2.31  7.199558           Line   line__11
# 2        2      1      3       2.33  7.199558           Line  line__128
# 3        3      3    119       0.98  7.199558           Line   line__88
# 4        4      4    123       0.94  7.199558           Line   line__44
#
#                                             geometry
# 0  LINESTRING (-122.47727 38.24211, -122.47366 38...
# 1  LINESTRING (-122.51861 38.25464, -122.49918 38...
# 2  LINESTRING (-122.51861 38.25464, -122.50139 38...
# 3  LINESTRING (-122.50139 38.24262, -122.4931 38....
# 4  LINESTRING (-122.53099 38.24637, -122.53114 38...

# %%
# transform_coordinate=True, noise_level="none"
gdf3.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       3.60  7.199558           Line  line__102
# 1        1      1      2       3.59  7.199558           Line   line__11
# 2        2      1      3       3.58  7.199558           Line  line__128
# 3        3      3    119       3.46  7.199558           Line   line__88
# 4        4      4    123       3.68  7.199558           Line   line__44
#
#                                             geometry
# 0    LINESTRING (-0.47362 0.23429, -0.46882 0.20218)
# 1    LINESTRING (-0.40613 0.15445, -0.40286 0.18664)
# 2     LINESTRING (-0.40613 0.15445, -0.4177 0.12435)
# 3     LINESTRING (-0.4177 0.12435, -0.44263 0.10567)
# 4  LINESTRING (-0.62087 -0.39656, -0.59517 -0.37564)

# %%
# transform_coordinate=True, noise_level="low"
gdf4.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       6.25  7.199558           Line  line__102
# 1        1      1      2       2.12  7.199558           Line   line__11
# 2        2      1      3       3.52  7.199558           Line  line__128
# 3        3      3    119       3.96  7.199558           Line   line__88
# 4        4      4    123       4.23  7.199558           Line   line__44
#
#                                            geometry
# 0   LINESTRING (-0.45265 0.23258, -0.46473 0.17759)
# 1    LINESTRING (-0.3937 0.15728, -0.41193 0.16295)
# 2    LINESTRING (-0.3937 0.15728, -0.41525 0.13398)
# 3   LINESTRING (-0.41525 0.13398, -0.44148 0.10976)
# 4  LINESTRING (-0.62556 -0.3913, -0.59345 -0.37072)

# %%
# Un-reduced circuit
gdf5.head()
# Out:
#    edge_id                    source      target  length_km        kv  \
# 0        0  p12udt1266-p12uhs0_1247x  p12udt1266       0.52  7.199558
# 1        1                p12udt77lv   p12ulv165       0.02  0.120089
# 2        2                p12udt77lv   p12ulv265       0.01  0.120089
# 3        3                p12udt77lv   p12ulv268       0.05  0.120089
# 4        4                p12udt77lv   p12ulv309       0.02  0.120089
#
#   component_type                             name  high_kv  low_kv  kva  \
# 0           Line  l(r:p12udt1266-p12uhs0_1247)_s1      NaN     NaN  NaN
# 1           Line        l(r:p12udt77lv-p12ulv165)      NaN     NaN  NaN
# 2           Line        l(r:p12udt77lv-p12ulv265)      NaN     NaN  NaN
# 3           Line        l(r:p12udt77lv-p12ulv268)      NaN     NaN  NaN
# 4           Line        l(r:p12udt77lv-p12ulv309)      NaN     NaN  NaN
#
#                                             geometry
# 0  LINESTRING (-122.48087 38.2472, -122.48538 38....
# 1  LINESTRING (-122.54487 38.20966, -122.54503 38...
# 2  LINESTRING (-122.54487 38.20966, -122.54478 38...
# 3  LINESTRING (-122.54487 38.20966, -122.54447 38...
# 4  LINESTRING (-122.54487 38.20966, -122.54497 38...

# %%
# transform_coordinate=False, noise_level="none"
gdf1.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d07dcdb3775fa4c504eaa52dcf53ab4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d07dcdb3775fa4c504eaa52dcf53ab4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d07dcdb3775fa4c504eaa52dcf53ab4 = L.map(
#                 &quot;map_9d07dcdb3775fa4c504eaa52dcf53ab4&quot;,
#                 {
#                     center: [38.23003879329826, -122.51837943554057],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9d07dcdb3775fa4c504eaa52dcf53ab4);
#
#
#
#
#
#             var tile_layer_9bdff14057a1ccfe8e057c5870c42f73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9bdff14057a1ccfe8e057c5870c42f73.addTo(map_9d07dcdb3775fa4c504eaa52dcf53ab4);
#
#
#             map_9d07dcdb3775fa4c504eaa52dcf53ab4.fitBounds(
#                 [[38.19733166011807, -122.55588415901687], [38.26274592647846, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_ad783544e10bba3b6fcb1e76a28ca316_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_ad783544e10bba3b6fcb1e76a28ca316_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ad783544e10bba3b6fcb1e76a28ca316_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_ad783544e10bba3b6fcb1e76a28ca316_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ad783544e10bba3b6fcb1e76a28ca316_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_ad783544e10bba3b6fcb1e76a28ca316.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ad783544e10bba3b6fcb1e76a28ca316_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ad783544e10bba3b6fcb1e76a28ca316 = L.geoJson(null, {
#                 onEachFeature: geo_json_ad783544e10bba3b6fcb1e76a28ca316_onEachFeature,
#
#                 style: geo_json_ad783544e10bba3b6fcb1e76a28ca316_styler,
#                 pointToLayer: geo_json_ad783544e10bba3b6fcb1e76a28ca316_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_ad783544e10bba3b6fcb1e76a28ca316_add (data) {
#             geo_json_ad783544e10bba3b6fcb1e76a28ca316
#                 .addData(data);
#         }
#             geo_json_ad783544e10bba3b6fcb1e76a28ca316_add({&quot;bbox&quot;: [-122.55588415901687, 38.19733166011807, -122.48087471206428, 38.26274592647846], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48538151936485, 38.247201582318546, -122.48087471206428, 38.24855675680422], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48087471206428, 38.247201582318546], [-122.48538151936485, 38.24855675680422]], &quot;type&qu

# %%
# transform_coordinate=False, noise_level="low"
gdf2.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2bc7c5fd732bfbdc2ce6392290bad60 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2bc7c5fd732bfbdc2ce6392290bad60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2bc7c5fd732bfbdc2ce6392290bad60 = L.map(
#                 &quot;map_b2bc7c5fd732bfbdc2ce6392290bad60&quot;,
#                 {
#                     center: [38.22423879520211, -122.52325776784264],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b2bc7c5fd732bfbdc2ce6392290bad60);
#
#
#
#
#
#             var tile_layer_5ab38f8dc02786350085e7745725970d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ab38f8dc02786350085e7745725970d.addTo(map_b2bc7c5fd732bfbdc2ce6392290bad60);
#
#
#             map_b2bc7c5fd732bfbdc2ce6392290bad60.fitBounds(
#                 [[38.169313978518886, -122.57285734480745], [38.27916361188534, -122.47365819087784]],
#                 {}
#             );
#
#
#         function geo_json_1360bd08b4d29428654c3e4717f542eb_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_1360bd08b4d29428654c3e4717f542eb_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1360bd08b4d29428654c3e4717f542eb_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_1360bd08b4d29428654c3e4717f542eb_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1360bd08b4d29428654c3e4717f542eb_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_1360bd08b4d29428654c3e4717f542eb.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1360bd08b4d29428654c3e4717f542eb_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1360bd08b4d29428654c3e4717f542eb = L.geoJson(null, {
#                 onEachFeature: geo_json_1360bd08b4d29428654c3e4717f542eb_onEachFeature,
#
#                 style: geo_json_1360bd08b4d29428654c3e4717f542eb_styler,
#                 pointToLayer: geo_json_1360bd08b4d29428654c3e4717f542eb_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_1360bd08b4d29428654c3e4717f542eb_add (data) {
#             geo_json_1360bd08b4d29428654c3e4717f542eb
#                 .addData(data);
#         }
#             geo_json_1360bd08b4d29428654c3e4717f542eb_add({&quot;bbox&quot;: [-122.57285734480745, 38.169313978518886, -122.47365819087784, 38.27916361188534], &quot;features&quot;: [{&quot;bbox&quot;: [-122.47727398603985, 38.24211460704196, -122.47365819087784, 38.260892597640364], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.47727398603985, 38.24211460704196], [-122.47365819087784, 38.260892597640364]], &quot;type&

# %%
# transform_coordinate=True, noise_level="none"
gdf3.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e61da482cbd41446d2149a69f782919 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e61da482cbd41446d2149a69f782919&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e61da482cbd41446d2149a69f782919 = L.map(
#                 &quot;map_1e61da482cbd41446d2149a69f782919&quot;,
#                 {
#                     center: [0.019103508636253264, -0.03527685160383259],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_1e61da482cbd41446d2149a69f782919);
#
#
#
#
#
#             var tile_layer_67f8983bc9d7cf8b98ce30558d5edb56 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67f8983bc9d7cf8b98ce30558d5edb56.addTo(map_1e61da482cbd41446d2149a69f782919);
#
#
#             map_1e61da482cbd41446d2149a69f782919.fitBounds(
#                 [[-0.7026368078732839, -1.0], [0.7408438251457904, 0.9294462967923348]],
#                 {}
#             );
#
#
#         function geo_json_cf71ec06f4446c3548ab92753898d84e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_cf71ec06f4446c3548ab92753898d84e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_cf71ec06f4446c3548ab92753898d84e_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_cf71ec06f4446c3548ab92753898d84e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_cf71ec06f4446c3548ab92753898d84e_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_cf71ec06f4446c3548ab92753898d84e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_cf71ec06f4446c3548ab92753898d84e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_cf71ec06f4446c3548ab92753898d84e = L.geoJson(null, {
#                 onEachFeature: geo_json_cf71ec06f4446c3548ab92753898d84e_onEachFeature,
#
#                 style: geo_json_cf71ec06f4446c3548ab92753898d84e_styler,
#                 pointToLayer: geo_json_cf71ec06f4446c3548ab92753898d84e_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_cf71ec06f4446c3548ab92753898d84e_add (data) {
#             geo_json_cf71ec06f4446c3548ab92753898d84e
#                 .addData(data);
#         }
#             geo_json_cf71ec06f4446c3548ab92753898d84e_add({&quot;bbox&quot;: [-1.0, -0.7026368078732839, 0.9294462967923348, 0.7408438251457904], &quot;features&quot;: [{&quot;bbox&quot;: [-0.4736212647387142, 0.20218112694732754, -0.4688215053829895, 0.23428640924990915], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.4736212647387142, 0.23428640924990915], [-0.4688215053829895, 0.20218112694732754]], &quot;type&quot;: &quot;LineS

# %%
# transform_coordinate=True, noise_level="low"
gdf4.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f91a76a6823f9fe8ea86fc310fb343f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f91a76a6823f9fe8ea86fc310fb343f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f91a76a6823f9fe8ea86fc310fb343f3 = L.map(
#                 &quot;map_f91a76a6823f9fe8ea86fc310fb343f3&quot;,
#                 {
#                     center: [0.018509403650682377, -0.03987045139669265],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_f91a76a6823f9fe8ea86fc310fb343f3);
#
#
#
#
#
#             var tile_layer_9db031b5d52d1136d9ad4217fad3a469 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9db031b5d52d1136d9ad4217fad3a469.addTo(map_f91a76a6823f9fe8ea86fc310fb343f3);
#
#
#             map_f91a76a6823f9fe8ea86fc310fb343f3.fitBounds(
#                 [[-0.7062567771160525, -1.0063709338955684], [0.7432755844174173, 0.9266300311021831]],
#                 {}
#             );
#
#
#         function geo_json_311852dc42238219b322b33552a941a9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_311852dc42238219b322b33552a941a9_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_311852dc42238219b322b33552a941a9_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_311852dc42238219b322b33552a941a9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_311852dc42238219b322b33552a941a9_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_311852dc42238219b322b33552a941a9.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_311852dc42238219b322b33552a941a9_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_311852dc42238219b322b33552a941a9 = L.geoJson(null, {
#                 onEachFeature: geo_json_311852dc42238219b322b33552a941a9_onEachFeature,
#
#                 style: geo_json_311852dc42238219b322b33552a941a9_styler,
#                 pointToLayer: geo_json_311852dc42238219b322b33552a941a9_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_311852dc42238219b322b33552a941a9_add (data) {
#             geo_json_311852dc42238219b322b33552a941a9
#                 .addData(data);
#         }
#             geo_json_311852dc42238219b322b33552a941a9_add({&quot;bbox&quot;: [-1.0063709338955684, -0.7062567771160525, 0.9266300311021831, 0.7432755844174173], &quot;features&quot;: [{&quot;bbox&quot;: [-0.4647280326818657, 0.1775885379747601, -0.452654718440458, 0.23258172866763208], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.452654718440458, 0.23258172866763208], [-0.4647280326818657, 0.1775885379747601]], &qu

# %%
# Un-reduced circuit
gdf5.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25bec2d8d7cc3c0905366b0d798e45f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25bec2d8d7cc3c0905366b0d798e45f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25bec2d8d7cc3c0905366b0d798e45f7 = L.map(
#                 &quot;map_25bec2d8d7cc3c0905366b0d798e45f7&quot;,
#                 {
#                     center: [38.229961196708544, -122.5186857132331],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_25bec2d8d7cc3c0905366b0d798e45f7);
#
#
#
#
#
#             var tile_layer_9bf497605246b2802abe787a7dd0cbcc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9bf497605246b2802abe787a7dd0cbcc.addTo(map_25bec2d8d7cc3c0905366b0d798e45f7);
#
#
#             map_25bec2d8d7cc3c0905366b0d798e45f7.fitBounds(
#                 [[38.1971361931719, -122.55649671440192], [38.262786200245195, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_9fb1f807dfae24059e13b43d4f8a272f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_9fb1f807dfae24059e13b43d4f8a272f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9fb1f807dfae24059e13b43d4f8a272f_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_9fb1f807dfae24059e13b43d4f8a272f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_9fb1f807dfae24059e13b43d4f8a272f_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_9fb1f807dfae24059e13b43d4f8a272f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9fb1f807dfae24059e13b43d4f8a272f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9fb1f807dfae24059e13b43d4f8a272f = L.geoJson(null, {
#                 onEachFeature: geo_json_9fb1f807dfae24059e13b43d4f8a272f_onEachFeature,
#
#                 style: geo_json_9fb1f807dfae24059e13b43d4f8a272f_styler,
#                 pointToLayer: geo_json_9fb1f807dfae24059e13b43d4f8a272f_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_9fb1f807dfae24059e13b43d4f8a272f_add (data) {
#             geo_json_9fb1f807dfae24059e13b43d4f8a272f
#                 .addData(data);
#         }
#             geo_json_9fb1f807dfae24059e13b43d4f8a272f_add({&quot;bbox&quot;: [-122.55649671440192, 38.1971361931719, -122.48087471206428, 38.262786200245195], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48538151936485, 38.247201582318546, -122.48087471206428, 38.24855675680422], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48087471206428, 38.247201582318546], [-122.48538151936485, 38.24855675680422]], &quot;type&qu

# %%
# # 🔍 Section 5: Comparing Multiple Graphs Side-by-Side

# # Load a second circuit (e.g., a modified version for comparison)
# master_dss_path2 = Path("../tests/data/smartds/Master.dss")
# ckt2 = get_ckt_from_opendss_model(master_dss_path2)
# reducer = OpenDSSModelReducer(master_dss_file=master_dss_path)
# reduced_ckt = reducer.reduce()
# ckt2 = reduced_ckt
# graph2 = get_graph_from_circuit(ckt2)
# gdf2 = graph_to_geodataframe(graph2)

# # Add 'category' column to both
# gdf["source"] = "Base"
# gdf2["source"] = "Variant"

# # Merge for comparison
# combined_gdf = pd.concat([gdf, gdf2], ignore_index=True)

# # Visualize both overlaid, color-coded by source
# combined_gdf.explore(column="source", legend=True, cmap="Set2")
