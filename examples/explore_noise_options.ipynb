# %% [markdown]
# 📘 Jupyter Notebook: Visualizing and Comparing Power System Graphs with GeoPandas

# %%
# 📦 Section 1: Imports & Setup
from pathlib import Path
import geopandas as gpd
import pandas as pd
from grid_reducer.utils import get_ckt_from_opendss_model
from grid_reducer.network import get_graph_from_circuit
from grid_reducer.plot import graph_to_geodataframe
from grid_reducer.reducer import OpenDSSModelReducer

# %%
# ⚡ Section 2: Load and Parse OpenDSS Circuit

# Specify the path to your DSS master file
master_dss_path = Path("../tests/data/smartds/Master.dss")

# Load the circuit object from the OpenDSS model
ckt = get_ckt_from_opendss_model(master_dss_path)
reducer = OpenDSSModelReducer(master_dss_file=master_dss_path)
reduced_ckt1 = reducer.reduce(transform_coordinate=False, noise_level="none")
reduced_ckt2 = reducer.reduce(transform_coordinate=False, noise_level="low")
reduced_ckt2a = reducer.reduce(transform_coordinate=False, noise_level="high")
reduced_ckt3 = reducer.reduce(transform_coordinate=True, noise_level="none")
reduced_ckt4 = reducer.reduce(transform_coordinate=True, noise_level="low")

# Create a NetworkX graph from the circuit
#graph = get_graph_from_circuit(ckt)
graph1 = get_graph_from_circuit(reduced_ckt1)
graph2 = get_graph_from_circuit(reduced_ckt2)
graph2a = get_graph_from_circuit(reduced_ckt2a)
graph3 = get_graph_from_circuit(reduced_ckt3)
graph4 = get_graph_from_circuit(reduced_ckt4)
graph5 = get_graph_from_circuit(ckt)

# Print basic info
#print(f"Number of nodes: {len(graph.nodes)}")
#print(f"Number of edges: {len(graph.edges)}")
# Out:
# Number of aggregated lines = 12
# Number of removed lines = 24
# Number of aggregated lines = 12
# Number of removed lines = 24
# Noise level:low; Epsilon: 5000
# Number of aggregated lines = 12
# Number of removed lines = 24
# Noise level:high; Epsilon: 2000
# Number of aggregated lines = 12
# Number of removed lines = 24
# Transforming coordinates...
# Time: 2.5114879608154297
# Number of aggregated lines = 12
# Number of removed lines = 24
# Transforming coordinates...
# Time: 0.341261625289917
# Noise level:low; Noise scale: 0.01

# %%
reduced_ckt1
# Out:
# Circuit(Name='reduced_ckt', DefaultBaseFreq=60.0, PreCommands=['! Last saved by AltDSS/DSS C-API Library version 0.14.5 revision 87d85c2622c8281b92255335bc7c09b11191b21d based on OpenDSS SVN 3723 [FPC 3.2.2] (64-bit build) MVMULT INCREMENTAL_Y CONTEXT_API PM 20240329033829 on 2025-06-24T17:21:04.272Z', 'Set EarthModel=Deri', 'Set VoltageBases=[ 0.12 0.208 0.48 7.2 12.47]'], PostCommands=['Set ControlMode=Static', 'Set Random=Gaussian', 'Set frequency=60', 'Set stepsize=0.001', 'Set number=100', 'Set tolerance=0.0001', 'Set maxiterations=15', 'Set miniterations=2', 'Set loadmodel=PowerFlow', 'Set loadmult=1', 'Set Normvminpu=0.95', 'Set Normvmaxpu=1.05', 'Set Emergvminpu=0.9', 'Set Emergvmaxpu=1.08', 'Set %mean=82.58', 'Set %stddev=15.31', 'Set LDCurve=', 'Set %growth=2.5', 'Set genkw=1000', 'Set genpf=1', 'Set capkvar=600', 'Set addtype=Generator', 'Set zonelock=No', 'Set ueweight=    1.00', 'Set lossweight=    1.00', 'Set ueregs=[10]', 'Set lossregs=[13]', 'Set algorithm=Normal', 'Set Trapezoidal=No', 'Set genmult=1', 'Set Basefrequency=60', 'Set harmonics=ALL', 'Set maxcontroliter=50'], Bus=[Bus(Name='0', X=-122.48087471206428, Y=38.247201582318546, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='1', X=-122.51227218507603, Y=38.26006897172899, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='2', X=-122.51293097429651, Y=38.26013011067854, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='3', X=-122.50090364359089, Y=38.246491189771085, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='4', X=-122.5391020838185, Y=38.24440274261924, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='5', X=-122.53865793832108, Y=38.24430706497998, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='6', X=-122.54727194446797, Y=38.24582202711049, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='7', X=-122.55070945139872, Y=38.24751488594113, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='8', X=-122.54124254268193, Y=38.244285004981585, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='9', X=-122.54045071510137, Y=38.24382846686455, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='10', X=-122.54119200706354, Y=38.24427068690155, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='11', X=-122.54013799152662, Y=38.24365882274168, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='12', X=-122.53737620453556, Y=38.24208985027718, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='13', X=-122.53782890467266, Y=38.243776039529166, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='14', X=-122.54894195383774, Y=38.2603996089285, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='15', X=-122.54777658270537, Y=38.26102459136288, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='16', X=-122.5487943062379, Y=38.26053354462685, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='17', X=-122.54796669821708, Y=38.259785481858756, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='18', X=-122.54180219835642, Y=38.25560999525482, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='19', X=-122.54125646428614, Y=38.25583513889025, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='20', X=-122.5417495953699, Y=38.25566743048635, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='21', X=-122.53978324825945, Y=38.26087739430247, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='22', X=-122.53850705547441, Y=38.26274592647846, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='23', X=-122.54121364546553, Y=38.255860685620625, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='24', X=-122.53618094001341, Y=38.253133359363076, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='25', X=-122.52936530629779, Y=38.242819163599144, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='26', X=-122.53041753856697, Y=38.24438640672556, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='27', X=-122.51647406465 ...

# %%
reduced_ckt2
# Out:
# Circuit(Name='reduced_ckt', DefaultBaseFreq=60.0, PreCommands=['! Last saved by AltDSS/DSS C-API Library version 0.14.5 revision 87d85c2622c8281b92255335bc7c09b11191b21d based on OpenDSS SVN 3723 [FPC 3.2.2] (64-bit build) MVMULT INCREMENTAL_Y CONTEXT_API PM 20240329033829 on 2025-06-24T17:21:04.272Z', 'Set EarthModel=Deri', 'Set VoltageBases=[ 0.12 0.208 0.48 7.2 12.47]'], PostCommands=['Set ControlMode=Static', 'Set Random=Gaussian', 'Set frequency=60', 'Set stepsize=0.001', 'Set number=100', 'Set tolerance=0.0001', 'Set maxiterations=15', 'Set miniterations=2', 'Set loadmodel=PowerFlow', 'Set loadmult=1', 'Set Normvminpu=0.95', 'Set Normvmaxpu=1.05', 'Set Emergvminpu=0.9', 'Set Emergvmaxpu=1.08', 'Set %mean=82.58', 'Set %stddev=15.31', 'Set LDCurve=', 'Set %growth=2.5', 'Set genkw=1000', 'Set genpf=1', 'Set capkvar=600', 'Set addtype=Generator', 'Set zonelock=No', 'Set ueweight=    1.00', 'Set lossweight=    1.00', 'Set ueregs=[10]', 'Set lossregs=[13]', 'Set algorithm=Normal', 'Set Trapezoidal=No', 'Set genmult=1', 'Set Basefrequency=60', 'Set harmonics=ALL', 'Set maxcontroliter=50'], Bus=[Bus(Name='0', X=-122.48090526551103, Y=38.247297306575874, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='1', X=-122.512392742909, Y=38.26018821204013, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='2', X=-122.51247109150438, Y=38.26069598935554, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='3', X=-122.5006458759567, Y=38.24715548763986, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='4', X=-122.53895801594186, Y=38.24433708128541, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='5', X=-122.53840711411759, Y=38.243845038803514, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='6', X=-122.54693383099985, Y=38.24559960246284, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='7', X=-122.55072214831571, Y=38.247460918985084, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='8', X=-122.54190871670771, Y=38.244186382066175, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='9', X=-122.54082696421814, Y=38.24380905952815, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='10', X=-122.54105642146455, Y=38.24438310516762, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='11', X=-122.54037124840559, Y=38.243232463433166, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='12', X=-122.53664623587743, Y=38.24126299182299, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='13', X=-122.53787918181831, Y=38.24377080533577, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='14', X=-122.54932086164986, Y=38.260127906012514, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='15', X=-122.54641689634182, Y=38.26220358951115, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='16', X=-122.54848636352195, Y=38.26033427474263, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='17', X=-122.54798118792485, Y=38.259856811569165, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='18', X=-122.5415936446799, Y=38.25599444673449, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='19', X=-122.54005008462879, Y=38.25548043736074, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='20', X=-122.54202814882996, Y=38.255931485806755, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='21', X=-122.53956382314757, Y=38.26101867908492, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='22', X=-122.53828200318787, Y=38.262392050017425, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='23', X=-122.54076655538456, Y=38.25602783773458, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='24', X=-122.5366467006064, Y=38.253264133658426, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='25', X=-122.52905963360699, Y=38.243258841776836, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='26', X=-122.53039949380545, Y=38.244399396331666, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='27', X=-122.51618551 ...

# %%
gdf1 = graph_to_geodataframe(graph1)
gdf2 = graph_to_geodataframe(graph2)
gdf2a = graph_to_geodataframe(graph2a)
gdf3 = graph_to_geodataframe(graph3)
gdf4 = graph_to_geodataframe(graph4)
gdf5 = graph_to_geodataframe(graph5)

# %%
# transform_coordinate=False, noise_level="none"
gdf1.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.52  7.199558           Line  line__121
# 1        1      1      2       0.07  7.199558           Line   line__42
# 2        2      1      3       1.97  7.199558           Line  line__128
# 3        3      3    119       0.01  7.199558           Line   line__51
# 4        4      4    123       0.00  7.199558           Line   line__21
#
#                                             geometry
# 0  LINESTRING (-122.48087 38.2472, -122.48538 38....
# 1  LINESTRING (-122.51227 38.26007, -122.51293 38...
# 2  LINESTRING (-122.51227 38.26007, -122.5009 38....
# 3  LINESTRING (-122.5009 38.24649, -122.5009 38.2...
# 4  LINESTRING (-122.5391 38.2444, -122.53911 38.2...

# %%
# transform_coordinate=False, noise_level="low"
gdf2.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.54  7.199558           Line  line__121
# 1        1      1      2       0.06  7.199558           Line   line__42
# 2        2      1      3       1.95  7.199558           Line  line__128
# 3        3      3    119       0.06  7.199558           Line   line__51
# 4        4      4    123       0.02  7.199558           Line   line__21
#
#                                             geometry
# 0  LINESTRING (-122.48091 38.2473, -122.48567 38....
# 1  LINESTRING (-122.51239 38.26019, -122.51247 38...
# 2  LINESTRING (-122.51239 38.26019, -122.50065 38...
# 3  LINESTRING (-122.50065 38.24716, -122.50083 38...
# 4  LINESTRING (-122.53896 38.24434, -122.53902 38...

# %%
# transform_coordinate=False, noise_level="high"
gdf2a.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.50  7.199558           Line  line__121
# 1        1      1      2       0.07  7.199558           Line   line__42
# 2        2      1      3       1.90  7.199558           Line  line__128
# 3        3      3    119       0.14  7.199558           Line   line__51
# 4        4      4    123       0.36  7.199558           Line   line__21
#
#                                             geometry
# 0  LINESTRING (-122.48059 38.24728, -122.4851 38....
# 1  LINESTRING (-122.51171 38.26033, -122.51159 38...
# 2  LINESTRING (-122.51171 38.26033, -122.50147 38...
# 3  LINESTRING (-122.50147 38.24666, -122.50041 38...
# 4  LINESTRING (-122.54109 38.24273, -122.53895 38...

# %%
# transform_coordinate=True, noise_level="none"
gdf3.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       3.60  7.199558           Line  line__121
# 1        1      1      2       3.59  7.199558           Line   line__42
# 2        2      1      3       3.58  7.199558           Line  line__128
# 3        3      3    119       3.46  7.199558           Line   line__51
# 4        4      4    123       3.68  7.199558           Line   line__21
#
#                                             geometry
# 0    LINESTRING (-0.47362 0.23429, -0.46882 0.20218)
# 1    LINESTRING (-0.40613 0.15445, -0.40286 0.18664)
# 2     LINESTRING (-0.40613 0.15445, -0.4177 0.12435)
# 3     LINESTRING (-0.4177 0.12435, -0.44263 0.10567)
# 4  LINESTRING (-0.62087 -0.39656, -0.59517 -0.37564)

# %%
# transform_coordinate=True, noise_level="low"
gdf4.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       4.37  7.199558           Line  line__121
# 1        1      1      2       3.89  7.199558           Line   line__42
# 2        2      1      3       2.22  7.199558           Line  line__128
# 3        3      3    119       4.35  7.199558           Line   line__51
# 4        4      4    123       4.52  7.199558           Line   line__21
#
#                                            geometry
# 0   LINESTRING (-0.48589 0.22893, -0.46146 0.19802)
# 1    LINESTRING (-0.4089 0.14823, -0.41039 0.18329)
# 2     LINESTRING (-0.4089 0.14823, -0.41861 0.1307)
# 3    LINESTRING (-0.41861 0.1307, -0.43064 0.09342)
# 4  LINESTRING (-0.6326 -0.40997, -0.60009 -0.38547)

# %%
# Un-reduced circuit
gdf5.head()
# Out:
#    edge_id                    source      target  length_km        kv  \
# 0        0  p12udt1266-p12uhs0_1247x  p12udt1266       0.52  7.199558
# 1        1                p12udt77lv   p12ulv165       0.02  0.120089
# 2        2                p12udt77lv   p12ulv265       0.01  0.120089
# 3        3                p12udt77lv   p12ulv268       0.05  0.120089
# 4        4                p12udt77lv   p12ulv309       0.02  0.120089
#
#   component_type                             name  high_kv  low_kv  kva  \
# 0           Line  l(r:p12udt1266-p12uhs0_1247)_s1      NaN     NaN  NaN
# 1           Line        l(r:p12udt77lv-p12ulv165)      NaN     NaN  NaN
# 2           Line        l(r:p12udt77lv-p12ulv265)      NaN     NaN  NaN
# 3           Line        l(r:p12udt77lv-p12ulv268)      NaN     NaN  NaN
# 4           Line        l(r:p12udt77lv-p12ulv309)      NaN     NaN  NaN
#
#                                             geometry
# 0  LINESTRING (-122.48087 38.2472, -122.48538 38....
# 1  LINESTRING (-122.54487 38.20966, -122.54503 38...
# 2  LINESTRING (-122.54487 38.20966, -122.54478 38...
# 3  LINESTRING (-122.54487 38.20966, -122.54447 38...
# 4  LINESTRING (-122.54487 38.20966, -122.54497 38...

# %%
gdf1["source"] = "Base"
gdf2["source"] = "LowNoise"
#gdf2a["source"] = "HighNoise"
combined_gdf = pd.concat([gdf1, gdf2], ignore_index=True)

# %%
# Combined map
''' unique_sources = combined_gdf['source'].unique()
color_map = {source: color for source, color in zip(unique_sources, ['#e41a1c','#377eb8','#4daf4a'])}
combined_gdf['color'] = combined_gdf['source'].map(color_map) '''
m = combined_gdf.explore(column="source", legend=True, cmap="Set1", style_kwds={
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },)
m.save("combined_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4470b8a3c445e18b8a41da89f99216e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend source&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;source&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e41a1c&#x27;&gt;&lt;/span&gt;Base&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#999999&#x27;&gt;&lt;/span&gt;LowNoise&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4470b8a3c445e18b8a41da89f99216e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4470b8a3c445e18b8a41da89f99216e3 = L.map(
#                 &quot;map_4470b8a3c445e18b8a41da89f99216e3&quot;,
#                 {
#                     center: [38.23003072820557, -122.51837943554057],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_4470b8a3c445e18b8a41da89f99216e3);
#
#
#
#
#
#             var tile_layer_60997dec64df98e3341bd08685d0b621 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_60997dec64df98e3341bd08685d0b621.addTo(map_4470b8a3c445e18b8a41da89f99216e3);
#
#
#             map_4470b8a3c445e18b8a41da89f99216e3.fitBounds(
#                 [[38.19731552993268, -122.55588415901687], [38.26274592647846, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_c502e8d5ce29e238cf978cedc2e40a2d_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&

# %%
# transform_coordinate=False, noise_level="none"
gdf1.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_252f46d4bd6f52f182d8d69aa420412b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_252f46d4bd6f52f182d8d69aa420412b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_252f46d4bd6f52f182d8d69aa420412b = L.map(
#                 &quot;map_252f46d4bd6f52f182d8d69aa420412b&quot;,
#                 {
#                     center: [38.23003879329826, -122.51837943554057],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_252f46d4bd6f52f182d8d69aa420412b);
#
#
#
#
#
#             var tile_layer_22b321564536abfe2968eee91b1347e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22b321564536abfe2968eee91b1347e1.addTo(map_252f46d4bd6f52f182d8d69aa420412b);
#
#
#             map_252f46d4bd6f52f182d8d69aa420412b.fitBounds(
#                 [[38.19733166011807, -122.55588415901687], [38.26274592647846, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_decb8410e26077a7b03290b8479fd0d5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_decb8410e26077a7b03290b8479fd0d5_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_decb8410e26077a7b03290b8479fd0d5_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_decb8410e26077a7b03290b8479fd0d5_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_decb8410e26077a7b03290b8479fd0d5_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_decb8410e26077a7b03290b8479fd0d5.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_decb8410e26077a7b03290b8479fd0d5_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_decb8410e26077a7b03290b8479fd0d5 = L.geoJson(null, {
#                 onEachFeature: geo_json_decb8410e26077a7b03290b8479fd0d5_onEachFeature,
#
#                 style: geo_json_decb8410e26077a7b03290b8479fd0d5_styler,
#                 pointToLayer: geo_json_decb8410e26077a7b03290b8479fd0d5_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_decb8410e26077a7b03290b8479fd0d5_add (data) {
#             geo_json_decb8410e26077a7b03290b8479fd0d5
#                 .addData(data);
#         }
#             geo_json_decb8410e26077a7b03290b8479fd0d5_add({&quot;bbox&quot;: [-122.55588415901687, 38.19733166011807, -122.48087471206428, 38.26274592647846], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48538151936485, 38.247201582318546, -122.48087471206428, 38.24855675680422], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48087471206428, 38.247201582318546], [-122.48538151936485, 38.24855675680422]], &quot;type&qu

# %%
# transform_coordinate=False, noise_level="low"
gdf2.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec12f31e8f2b39653092e1d8041a3abf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec12f31e8f2b39653092e1d8041a3abf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec12f31e8f2b39653092e1d8041a3abf = L.map(
#                 &quot;map_ec12f31e8f2b39653092e1d8041a3abf&quot;,
#                 {
#                     center: [38.22985378997505, -122.51839219707256],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ec12f31e8f2b39653092e1d8041a3abf);
#
#
#
#
#
#             var tile_layer_bf1820f694ca9a28ed6b7124ef91437e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf1820f694ca9a28ed6b7124ef91437e.addTo(map_ec12f31e8f2b39653092e1d8041a3abf);
#
#
#             map_ec12f31e8f2b39653092e1d8041a3abf.fitBounds(
#                 [[38.19731552993268, -122.5558791286341], [38.262392050017425, -122.48090526551103]],
#                 {}
#             );
#
#
#         function geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe = L.geoJson(null, {
#                 onEachFeature: geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_onEachFeature,
#
#                 style: geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_styler,
#                 pointToLayer: geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_add (data) {
#             geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe
#                 .addData(data);
#         }
#             geo_json_e40a4ed2ad287415a8187a4dbb7d5ebe_add({&quot;bbox&quot;: [-122.5558791286341, 38.19731552993268, -122.48090526551103, 38.262392050017425], &quot;features&quot;: [{&quot;bbox&quot;: [-122.4856669845035, 38.247297306575874, -122.48090526551103, 38.24841804113435], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48090526551103, 38.247297306575874], [-122.4856669845035, 38.24841804113435]], &quot;type&quot

# %%
# transform_coordinate=False, noise_level="high"
gdf2a.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ab4cbf42c7d831b116c4106e3ccf144 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ab4cbf42c7d831b116c4106e3ccf144&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ab4cbf42c7d831b116c4106e3ccf144 = L.map(
#                 &quot;map_9ab4cbf42c7d831b116c4106e3ccf144&quot;,
#                 {
#                     center: [38.23077017231167, -122.51833843877705],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9ab4cbf42c7d831b116c4106e3ccf144);
#
#
#
#
#
#             var tile_layer_1ca758fd381a20d43e94da9d803d993f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ca758fd381a20d43e94da9d803d993f.addTo(map_9ab4cbf42c7d831b116c4106e3ccf144);
#
#
#             map_9ab4cbf42c7d831b116c4106e3ccf144.fitBounds(
#                 [[38.19820953748723, -122.55609022338604], [38.263330807136114, -122.48058665416808]],
#                 {}
#             );
#
#
#         function geo_json_c8ca73697df07958b402956d345c1923_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_c8ca73697df07958b402956d345c1923_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c8ca73697df07958b402956d345c1923_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_c8ca73697df07958b402956d345c1923_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c8ca73697df07958b402956d345c1923_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_c8ca73697df07958b402956d345c1923.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c8ca73697df07958b402956d345c1923_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c8ca73697df07958b402956d345c1923 = L.geoJson(null, {
#                 onEachFeature: geo_json_c8ca73697df07958b402956d345c1923_onEachFeature,
#
#                 style: geo_json_c8ca73697df07958b402956d345c1923_styler,
#                 pointToLayer: geo_json_c8ca73697df07958b402956d345c1923_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_c8ca73697df07958b402956d345c1923_add (data) {
#             geo_json_c8ca73697df07958b402956d345c1923
#                 .addData(data);
#         }
#             geo_json_c8ca73697df07958b402956d345c1923_add({&quot;bbox&quot;: [-122.55609022338604, 38.19820953748723, -122.48058665416808, 38.263330807136114], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48510156832297, 38.2472842212237, -122.48058665416808, 38.24740735378031], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48058665416808, 38.2472842212237], [-122.48510156832297, 38.24740735378031]], &quot;type&quot

# %%
# transform_coordinate=True, noise_level="none"
gdf3.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eaf99ef8c39cae692c1b2698f284b48f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eaf99ef8c39cae692c1b2698f284b48f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eaf99ef8c39cae692c1b2698f284b48f = L.map(
#                 &quot;map_eaf99ef8c39cae692c1b2698f284b48f&quot;,
#                 {
#                     center: [0.019103508636253264, -0.03527685160383259],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_eaf99ef8c39cae692c1b2698f284b48f);
#
#
#
#
#
#             var tile_layer_89dcfbe546d5372f9df62a0e02c44d34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_89dcfbe546d5372f9df62a0e02c44d34.addTo(map_eaf99ef8c39cae692c1b2698f284b48f);
#
#
#             map_eaf99ef8c39cae692c1b2698f284b48f.fitBounds(
#                 [[-0.7026368078732839, -1.0], [0.7408438251457904, 0.9294462967923348]],
#                 {}
#             );
#
#
#         function geo_json_2df5d6af21732899894333dc2ee460cc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_2df5d6af21732899894333dc2ee460cc_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_2df5d6af21732899894333dc2ee460cc_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_2df5d6af21732899894333dc2ee460cc_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_2df5d6af21732899894333dc2ee460cc_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_2df5d6af21732899894333dc2ee460cc.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_2df5d6af21732899894333dc2ee460cc_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_2df5d6af21732899894333dc2ee460cc = L.geoJson(null, {
#                 onEachFeature: geo_json_2df5d6af21732899894333dc2ee460cc_onEachFeature,
#
#                 style: geo_json_2df5d6af21732899894333dc2ee460cc_styler,
#                 pointToLayer: geo_json_2df5d6af21732899894333dc2ee460cc_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_2df5d6af21732899894333dc2ee460cc_add (data) {
#             geo_json_2df5d6af21732899894333dc2ee460cc
#                 .addData(data);
#         }
#             geo_json_2df5d6af21732899894333dc2ee460cc_add({&quot;bbox&quot;: [-1.0, -0.7026368078732839, 0.9294462967923348, 0.7408438251457904], &quot;features&quot;: [{&quot;bbox&quot;: [-0.4736212647387142, 0.20218112694732754, -0.4688215053829895, 0.23428640924990915], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.4736212647387142, 0.23428640924990915], [-0.4688215053829895, 0.20218112694732754]], &quot;type&quot;: &quot;LineS

# %%
# transform_coordinate=True, noise_level="low"
gdf4.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ee5b452cb555a89ecd0a53a4f9b63b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ee5b452cb555a89ecd0a53a4f9b63b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ee5b452cb555a89ecd0a53a4f9b63b9 = L.map(
#                 &quot;map_3ee5b452cb555a89ecd0a53a4f9b63b9&quot;,
#                 {
#                     center: [0.0232183168533584, -0.033427502515994134],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3ee5b452cb555a89ecd0a53a4f9b63b9);
#
#
#
#
#
#             var tile_layer_cab2a4fdd63a3556955cd3bc3c7da3bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cab2a4fdd63a3556955cd3bc3c7da3bf.addTo(map_3ee5b452cb555a89ecd0a53a4f9b63b9);
#
#
#             map_3ee5b452cb555a89ecd0a53a4f9b63b9.fitBounds(
#                 [[-0.6995551996810664, -0.9846766638743479], [0.7459918333877832, 0.9178216588423597]],
#                 {}
#             );
#
#
#         function geo_json_19fb95cf01d67a71717f4f24e4c07309_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_19fb95cf01d67a71717f4f24e4c07309_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_19fb95cf01d67a71717f4f24e4c07309_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_19fb95cf01d67a71717f4f24e4c07309_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_19fb95cf01d67a71717f4f24e4c07309_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_19fb95cf01d67a71717f4f24e4c07309.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_19fb95cf01d67a71717f4f24e4c07309_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_19fb95cf01d67a71717f4f24e4c07309 = L.geoJson(null, {
#                 onEachFeature: geo_json_19fb95cf01d67a71717f4f24e4c07309_onEachFeature,
#
#                 style: geo_json_19fb95cf01d67a71717f4f24e4c07309_styler,
#                 pointToLayer: geo_json_19fb95cf01d67a71717f4f24e4c07309_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_19fb95cf01d67a71717f4f24e4c07309_add (data) {
#             geo_json_19fb95cf01d67a71717f4f24e4c07309
#                 .addData(data);
#         }
#             geo_json_19fb95cf01d67a71717f4f24e4c07309_add({&quot;bbox&quot;: [-0.9846766638743479, -0.6995551996810664, 0.9178216588423597, 0.7459918333877832], &quot;features&quot;: [{&quot;bbox&quot;: [-0.48588942881224745, 0.19802468096965767, -0.46145606803427, 0.2289305817176892], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.48588942881224745, 0.2289305817176892], [-0.46145606803427, 0.19802468096965767]], &quo

# %%
# Un-reduced circuit
gdf5.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9477499a55b3acb89960597f6ca6177c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9477499a55b3acb89960597f6ca6177c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9477499a55b3acb89960597f6ca6177c = L.map(
#                 &quot;map_9477499a55b3acb89960597f6ca6177c&quot;,
#                 {
#                     center: [38.229961196708544, -122.5186857132331],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_9477499a55b3acb89960597f6ca6177c);
#
#
#
#
#
#             var tile_layer_0500ed11440c0de4e01ea84c2abc1c2f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0500ed11440c0de4e01ea84c2abc1c2f.addTo(map_9477499a55b3acb89960597f6ca6177c);
#
#
#             map_9477499a55b3acb89960597f6ca6177c.fitBounds(
#                 [[38.1971361931719, -122.55649671440192], [38.262786200245195, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_87be3fb29a81b3051c9432e9c50aa3ad_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_87be3fb29a81b3051c9432e9c50aa3ad_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_87be3fb29a81b3051c9432e9c50aa3ad_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_87be3fb29a81b3051c9432e9c50aa3ad_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_87be3fb29a81b3051c9432e9c50aa3ad_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_87be3fb29a81b3051c9432e9c50aa3ad.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_87be3fb29a81b3051c9432e9c50aa3ad_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_87be3fb29a81b3051c9432e9c50aa3ad = L.geoJson(null, {
#                 onEachFeature: geo_json_87be3fb29a81b3051c9432e9c50aa3ad_onEachFeature,
#
#                 style: geo_json_87be3fb29a81b3051c9432e9c50aa3ad_styler,
#                 pointToLayer: geo_json_87be3fb29a81b3051c9432e9c50aa3ad_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_87be3fb29a81b3051c9432e9c50aa3ad_add (data) {
#             geo_json_87be3fb29a81b3051c9432e9c50aa3ad
#                 .addData(data);
#         }
#             geo_json_87be3fb29a81b3051c9432e9c50aa3ad_add({&quot;bbox&quot;: [-122.55649671440192, 38.1971361931719, -122.48087471206428, 38.262786200245195], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48538151936485, 38.247201582318546, -122.48087471206428, 38.24855675680422], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48087471206428, 38.247201582318546], [-122.48538151936485, 38.24855675680422]], &quot;type&qu
