# %% [markdown]
# 📘 Jupyter Notebook: Visualizing and Comparing Power System Graphs with GeoPandas

# %%
# 📦 Section 1: Imports & Setup
from pathlib import Path
import geopandas as gpd
import pandas as pd
from grid_reducer.utils import get_ckt_from_opendss_model
from grid_reducer.network import get_graph_from_circuit
from grid_reducer.plot import graph_to_geodataframe
from grid_reducer.reducer import OpenDSSModelReducer

# %%
# ⚡ Section 2: Load and Parse OpenDSS Circuit

# Specify the path to your DSS master file
master_dss_path = Path("../tests/data/smartds/Master.dss")

# Load the circuit object from the OpenDSS model
ckt = get_ckt_from_opendss_model(master_dss_path)
reducer = OpenDSSModelReducer(master_dss_file=master_dss_path)
reduced_ckt1 = reducer.reduce(transform_coordinate=False, noise_level="none")
reduced_ckt2 = reducer.reduce(transform_coordinate=False, noise_level="low")
reduced_ckt2a = reducer.reduce(transform_coordinate=False, noise_level="high")
reduced_ckt3 = reducer.reduce(transform_coordinate=True, noise_level="none")
reduced_ckt4 = reducer.reduce(transform_coordinate=True, noise_level="low")

# Create a NetworkX graph from the circuit
#graph = get_graph_from_circuit(ckt)
graph1 = get_graph_from_circuit(reduced_ckt1)
graph2 = get_graph_from_circuit(reduced_ckt2)
graph2a = get_graph_from_circuit(reduced_ckt2a)
graph3 = get_graph_from_circuit(reduced_ckt3)
graph4 = get_graph_from_circuit(reduced_ckt4)
graph5 = get_graph_from_circuit(ckt)

# Print basic info
#print(f"Number of nodes: {len(graph.nodes)}")
#print(f"Number of edges: {len(graph.edges)}")
# Out:
# Number of aggregated lines = 12
# Number of removed lines = 24
# Number of aggregated lines = 12
# Number of removed lines = 24
# Noise level:low; Epsilon: 5000
# Number of aggregated lines = 12
# Number of removed lines = 24
# Noise level:high; Epsilon: 2000
# Number of aggregated lines = 12
# Number of removed lines = 24
# Transforming coordinates...
# Time: 0.5907080173492432
# Number of aggregated lines = 12
# Number of removed lines = 24
# Transforming coordinates...
# Time: 0.24812889099121094
# Noise level:low; Noise scale: 0.01

# %%
reduced_ckt1
# Out:
# Circuit(Name='reduced_ckt', DefaultBaseFreq=60.0, PreCommands=['! Last saved by AltDSS/DSS C-API Library version 0.14.5 revision 87d85c2622c8281b92255335bc7c09b11191b21d based on OpenDSS SVN 3723 [FPC 3.2.2] (64-bit build) MVMULT INCREMENTAL_Y CONTEXT_API PM 20240329033829 on 2025-06-24T18:03:19.502Z', 'Set EarthModel=Deri', 'Set VoltageBases=[ 0.12 0.208 0.48 7.2 12.47]'], PostCommands=['Set ControlMode=Static', 'Set Random=Gaussian', 'Set frequency=60', 'Set stepsize=0.001', 'Set number=100', 'Set tolerance=0.0001', 'Set maxiterations=15', 'Set miniterations=2', 'Set loadmodel=PowerFlow', 'Set loadmult=1', 'Set Normvminpu=0.95', 'Set Normvmaxpu=1.05', 'Set Emergvminpu=0.9', 'Set Emergvmaxpu=1.08', 'Set %mean=82.58', 'Set %stddev=15.31', 'Set LDCurve=', 'Set %growth=2.5', 'Set genkw=1000', 'Set genpf=1', 'Set capkvar=600', 'Set addtype=Generator', 'Set zonelock=No', 'Set ueweight=    1.00', 'Set lossweight=    1.00', 'Set ueregs=[10]', 'Set lossregs=[13]', 'Set algorithm=Normal', 'Set Trapezoidal=No', 'Set genmult=1', 'Set Basefrequency=60', 'Set harmonics=ALL', 'Set maxcontroliter=50'], Bus=[Bus(Name='0', X=-122.48087471206428, Y=38.247201582318546, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='1', X=-122.51227218507603, Y=38.26006897172899, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='2', X=-122.51293097429651, Y=38.26013011067854, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='3', X=-122.50090364359089, Y=38.246491189771085, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='4', X=-122.5391020838185, Y=38.24440274261924, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='5', X=-122.53865793832108, Y=38.24430706497998, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='6', X=-122.54727194446797, Y=38.24582202711049, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='7', X=-122.55070945139872, Y=38.24751488594113, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='8', X=-122.54124254268193, Y=38.244285004981585, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='9', X=-122.54045071510137, Y=38.24382846686455, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='10', X=-122.54119200706354, Y=38.24427068690155, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='11', X=-122.54013799152662, Y=38.24365882274168, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='12', X=-122.53737620453556, Y=38.24208985027718, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='13', X=-122.53782890467266, Y=38.243776039529166, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='14', X=-122.54894195383774, Y=38.2603996089285, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='15', X=-122.54777658270537, Y=38.26102459136288, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='16', X=-122.5487943062379, Y=38.26053354462685, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='17', X=-122.54796669821708, Y=38.259785481858756, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='18', X=-122.54180219835642, Y=38.25560999525482, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='19', X=-122.54125646428614, Y=38.25583513889025, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='20', X=-122.5417495953699, Y=38.25566743048635, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='21', X=-122.53978324825945, Y=38.26087739430247, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='22', X=-122.53850705547441, Y=38.26274592647846, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='23', X=-122.54121364546553, Y=38.255860685620625, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='24', X=-122.53618094001341, Y=38.253133359363076, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='25', X=-122.52936530629779, Y=38.242819163599144, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='26', X=-122.53041753856697, Y=38.24438640672556, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='27', X=-122.51647406465 ...

# %%
reduced_ckt2
# Out:
# Circuit(Name='reduced_ckt', DefaultBaseFreq=60.0, PreCommands=['! Last saved by AltDSS/DSS C-API Library version 0.14.5 revision 87d85c2622c8281b92255335bc7c09b11191b21d based on OpenDSS SVN 3723 [FPC 3.2.2] (64-bit build) MVMULT INCREMENTAL_Y CONTEXT_API PM 20240329033829 on 2025-06-24T18:03:19.502Z', 'Set EarthModel=Deri', 'Set VoltageBases=[ 0.12 0.208 0.48 7.2 12.47]'], PostCommands=['Set ControlMode=Static', 'Set Random=Gaussian', 'Set frequency=60', 'Set stepsize=0.001', 'Set number=100', 'Set tolerance=0.0001', 'Set maxiterations=15', 'Set miniterations=2', 'Set loadmodel=PowerFlow', 'Set loadmult=1', 'Set Normvminpu=0.95', 'Set Normvmaxpu=1.05', 'Set Emergvminpu=0.9', 'Set Emergvmaxpu=1.08', 'Set %mean=82.58', 'Set %stddev=15.31', 'Set LDCurve=', 'Set %growth=2.5', 'Set genkw=1000', 'Set genpf=1', 'Set capkvar=600', 'Set addtype=Generator', 'Set zonelock=No', 'Set ueweight=    1.00', 'Set lossweight=    1.00', 'Set ueregs=[10]', 'Set lossregs=[13]', 'Set algorithm=Normal', 'Set Trapezoidal=No', 'Set genmult=1', 'Set Basefrequency=60', 'Set harmonics=ALL', 'Set maxcontroliter=50'], Bus=[Bus(Name='0', X=-122.48105486870585, Y=38.24732644658309, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='1', X=-122.51208830391647, Y=38.26011162561191, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='2', X=-122.51319221072005, Y=38.25999546822106, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='3', X=-122.50050585956214, Y=38.24624531411206, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='4', X=-122.53924566693692, Y=38.244083642653926, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='5', X=-122.53823474684991, Y=38.24454718259455, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='6', X=-122.54721243799929, Y=38.24571098496036, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='7', X=-122.55063221727617, Y=38.247058104401205, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='8', X=-122.54112416498147, Y=38.243828370239605, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='9', X=-122.54044211716392, Y=38.244661797613475, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='10', X=-122.54133258748757, Y=38.24426083172873, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='11', X=-122.53995763940021, Y=38.243452677525, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='12', X=-122.53743510279062, Y=38.24209763534796, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='13', X=-122.53765201174701, Y=38.24410058176427, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='14', X=-122.54877280804257, Y=38.260263086291495, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='15', X=-122.54810520439143, Y=38.26130572825351, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='16', X=-122.54891892034067, Y=38.26053759263318, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='17', X=-122.54744479260509, Y=38.26006501248356, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='18', X=-122.54148983801817, Y=38.2550128238669, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='19', X=-122.5411029741482, Y=38.25648793955325, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='20', X=-122.54141453863568, Y=38.25537900651702, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='21', X=-122.53953774801671, Y=38.2608018350054, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='22', X=-122.53855789582559, Y=38.26275676704939, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='23', X=-122.5408860289593, Y=38.25594452948417, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='24', X=-122.53603761745262, Y=38.25380352345745, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='25', X=-122.52939305176686, Y=38.242698765458194, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='26', X=-122.53077010225141, Y=38.24444001948905, kVLN=7.199557856794634, kVLL=None, Keep=None), Bus(Name='27', X=-122.51567995258601, ...

# %%
gdf1 = graph_to_geodataframe(graph1)
gdf2 = graph_to_geodataframe(graph2)
gdf2a = graph_to_geodataframe(graph2a)
gdf3 = graph_to_geodataframe(graph3)
gdf4 = graph_to_geodataframe(graph4)
gdf5 = graph_to_geodataframe(graph5)

# %%
# transform_coordinate=False, noise_level="none"
gdf1.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.52  7.199558           Line   line__70
# 1        1      1      2       0.07  7.199558           Line  line__125
# 2        2      1      3       1.97  7.199558           Line  line__128
# 3        3      3    119       0.01  7.199558           Line   line__42
# 4        4      4      5       0.05  7.199558           Line   line__73
#
#                                             geometry
# 0  LINESTRING (-122.48087 38.2472, -122.48538 38....
# 1  LINESTRING (-122.51227 38.26007, -122.51293 38...
# 2  LINESTRING (-122.51227 38.26007, -122.5009 38....
# 3  LINESTRING (-122.5009 38.24649, -122.5009 38.2...
# 4  LINESTRING (-122.5391 38.2444, -122.53866 38.2...

# %%
# transform_coordinate=False, noise_level="low"
gdf2.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.48  7.199558           Line   line__70
# 1        1      1      2       0.12  7.199558           Line  line__125
# 2        2      1      3       2.01  7.199558           Line  line__128
# 3        3      3    119       0.07  7.199558           Line   line__42
# 4        4      4      5       0.12  7.199558           Line   line__73
#
#                                             geometry
# 0  LINESTRING (-122.48105 38.24733, -122.48523 38...
# 1  LINESTRING (-122.51209 38.26011, -122.51319 38...
# 2  LINESTRING (-122.51209 38.26011, -122.50051 38...
# 3  LINESTRING (-122.50051 38.24625, -122.5011 38....
# 4  LINESTRING (-122.53925 38.24408, -122.53823 38...

# %%
# transform_coordinate=False, noise_level="high"
gdf2a.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       0.68  7.199558           Line   line__70
# 1        1      1      2       0.53  7.199558           Line  line__125
# 2        2      1      3       2.06  7.199558           Line  line__128
# 3        3      3    119       0.18  7.199558           Line   line__42
# 4        4      4      5       0.03  7.199558           Line   line__73
#
#                                             geometry
# 0  LINESTRING (-122.48089 38.24733, -122.48664 38...
# 1  LINESTRING (-122.51143 38.26009, -122.51621 38...
# 2  LINESTRING (-122.51143 38.26009, -122.50055 38...
# 3  LINESTRING (-122.50055 38.24509, -122.49964 38...
# 4  LINESTRING (-122.53889 38.24385, -122.53898 38...

# %%
# transform_coordinate=True, noise_level="none"
gdf3.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       3.60  7.199558           Line   line__70
# 1        1      1      2       3.59  7.199558           Line  line__125
# 2        2      1      3       3.58  7.199558           Line  line__128
# 3        3      3    119       3.46  7.199558           Line   line__42
# 4        4      4      5       3.56  7.199558           Line   line__73
#
#                                             geometry
# 0    LINESTRING (-0.47362 0.23429, -0.46882 0.20218)
# 1    LINESTRING (-0.40613 0.15445, -0.40286 0.18664)
# 2     LINESTRING (-0.40613 0.15445, -0.4177 0.12435)
# 3     LINESTRING (-0.4177 0.12435, -0.44263 0.10567)
# 4  LINESTRING (-0.62087 -0.39656, -0.64385 -0.41892)

# %%
# transform_coordinate=True, noise_level="low"
gdf4.head()
# Out:
#    edge_id source target  length_km        kv component_type       name  \
# 0        0      0    121       3.90  7.199558           Line   line__70
# 1        1      1      2       4.45  7.199558           Line  line__125
# 2        2      1      3       3.16  7.199558           Line  line__128
# 3        3      3    119       4.66  7.199558           Line   line__42
# 4        4      4      5       2.07  7.199558           Line   line__73
#
#                                            geometry
# 0   LINESTRING (-0.47124 0.23309, -0.46157 0.19929)
# 1    LINESTRING (-0.41168 0.1647, -0.39619 0.20172)
# 2    LINESTRING (-0.41168 0.1647, -0.41484 0.13641)
# 3    LINESTRING (-0.41484 0.13641, -0.44188 0.1043)
# 4  LINESTRING (-0.62449 -0.40682, -0.64084 -0.4158)

# %%
# Un-reduced circuit
gdf5.head()
# Out:
#    edge_id                    source      target  length_km        kv  \
# 0        0  p12udt1266-p12uhs0_1247x  p12udt1266       0.52  7.199558
# 1        1                p12udt77lv   p12ulv165       0.02  0.120089
# 2        2                p12udt77lv   p12ulv265       0.01  0.120089
# 3        3                p12udt77lv   p12ulv268       0.05  0.120089
# 4        4                p12udt77lv   p12ulv309       0.02  0.120089
#
#   component_type                             name  high_kv  low_kv  kva  \
# 0           Line  l(r:p12udt1266-p12uhs0_1247)_s1      NaN     NaN  NaN
# 1           Line        l(r:p12udt77lv-p12ulv165)      NaN     NaN  NaN
# 2           Line        l(r:p12udt77lv-p12ulv265)      NaN     NaN  NaN
# 3           Line        l(r:p12udt77lv-p12ulv268)      NaN     NaN  NaN
# 4           Line        l(r:p12udt77lv-p12ulv309)      NaN     NaN  NaN
#
#                                             geometry
# 0  LINESTRING (-122.48087 38.2472, -122.48538 38....
# 1  LINESTRING (-122.54487 38.20966, -122.54503 38...
# 2  LINESTRING (-122.54487 38.20966, -122.54478 38...
# 3  LINESTRING (-122.54487 38.20966, -122.54447 38...
# 4  LINESTRING (-122.54487 38.20966, -122.54497 38...

# %%
gdf1["source"] = "Base"
gdf2["source"] = "LowNoise"
#gdf2a["source"] = "HighNoise"
combined_gdf = pd.concat([gdf1, gdf2], ignore_index=True)

# %%
# Combined map

m = combined_gdf.explore(column="source", legend=True, cmap="Set1", style_kwds={
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },)
m.save("combined_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b054da881df1bc1d0a23018eb561f0ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend source&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;source&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e41a1c&#x27;&gt;&lt;/span&gt;Base&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#999999&#x27;&gt;&lt;/span&gt;LowNoise&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b054da881df1bc1d0a23018eb561f0ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b054da881df1bc1d0a23018eb561f0ee = L.map(
#                 &quot;map_b054da881df1bc1d0a23018eb561f0ee&quot;,
#                 {
#                     center: [38.2299597121047, -122.51837943554057],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b054da881df1bc1d0a23018eb561f0ee);
#
#
#
#
#
#             var tile_layer_b442731e3b3e3e5534d5b26fe6e3f136 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b442731e3b3e3e5534d5b26fe6e3f136.addTo(map_b054da881df1bc1d0a23018eb561f0ee);
#
#
#             map_b054da881df1bc1d0a23018eb561f0ee.fitBounds(
#                 [[38.19716265716001, -122.55588415901687], [38.26275676704939, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_4c71fdb8ea3ba8abefeb4812976b9eab_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;34&q

# %%
# transform_coordinate=False, noise_level="none"
gdf1.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b10a5d0b061d1db2179c155ba05e982f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b10a5d0b061d1db2179c155ba05e982f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b10a5d0b061d1db2179c155ba05e982f = L.map(
#                 &quot;map_b10a5d0b061d1db2179c155ba05e982f&quot;,
#                 {
#                     center: [38.23003879329826, -122.51837943554057],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b10a5d0b061d1db2179c155ba05e982f);
#
#
#
#
#
#             var tile_layer_340300abb47ab30f5b59b44d34232883 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_340300abb47ab30f5b59b44d34232883.addTo(map_b10a5d0b061d1db2179c155ba05e982f);
#
#
#             map_b10a5d0b061d1db2179c155ba05e982f.fitBounds(
#                 [[38.19733166011807, -122.55588415901687], [38.26274592647846, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_8f221c12002a5e4ec1ef8a23352dc16d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_8f221c12002a5e4ec1ef8a23352dc16d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8f221c12002a5e4ec1ef8a23352dc16d_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_8f221c12002a5e4ec1ef8a23352dc16d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8f221c12002a5e4ec1ef8a23352dc16d_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_8f221c12002a5e4ec1ef8a23352dc16d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8f221c12002a5e4ec1ef8a23352dc16d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8f221c12002a5e4ec1ef8a23352dc16d = L.geoJson(null, {
#                 onEachFeature: geo_json_8f221c12002a5e4ec1ef8a23352dc16d_onEachFeature,
#
#                 style: geo_json_8f221c12002a5e4ec1ef8a23352dc16d_styler,
#                 pointToLayer: geo_json_8f221c12002a5e4ec1ef8a23352dc16d_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_8f221c12002a5e4ec1ef8a23352dc16d_add (data) {
#             geo_json_8f221c12002a5e4ec1ef8a23352dc16d
#                 .addData(data);
#         }
#             geo_json_8f221c12002a5e4ec1ef8a23352dc16d_add({&quot;bbox&quot;: [-122.55588415901687, 38.19733166011807, -122.48087471206428, 38.26274592647846], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48538151936485, 38.247201582318546, -122.48087471206428, 38.24855675680422], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48087471206428, 38.247201582318546], [-122.48538151936485, 38.24855675680422]], &quot;type&qu

# %%
# transform_coordinate=False, noise_level="low"
gdf2.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f2b0c8a106a509e63a909869066d1c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f2b0c8a106a509e63a909869066d1c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f2b0c8a106a509e63a909869066d1c0 = L.map(
#                 &quot;map_8f2b0c8a106a509e63a909869066d1c0&quot;,
#                 {
#                     center: [38.2299597121047, -122.51836525016202],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_8f2b0c8a106a509e63a909869066d1c0);
#
#
#
#
#
#             var tile_layer_912411fc64644ff74550ffc3dc79bb31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_912411fc64644ff74550ffc3dc79bb31.addTo(map_8f2b0c8a106a509e63a909869066d1c0);
#
#
#             map_8f2b0c8a106a509e63a909869066d1c0.fitBounds(
#                 [[38.19716265716001, -122.55567563161817], [38.26275676704939, -122.48105486870585]],
#                 {}
#             );
#
#
#         function geo_json_f4dfff3269f262b5e9aea12b524772ce_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_f4dfff3269f262b5e9aea12b524772ce_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f4dfff3269f262b5e9aea12b524772ce_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_f4dfff3269f262b5e9aea12b524772ce_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f4dfff3269f262b5e9aea12b524772ce_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f4dfff3269f262b5e9aea12b524772ce.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f4dfff3269f262b5e9aea12b524772ce_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f4dfff3269f262b5e9aea12b524772ce = L.geoJson(null, {
#                 onEachFeature: geo_json_f4dfff3269f262b5e9aea12b524772ce_onEachFeature,
#
#                 style: geo_json_f4dfff3269f262b5e9aea12b524772ce_styler,
#                 pointToLayer: geo_json_f4dfff3269f262b5e9aea12b524772ce_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_f4dfff3269f262b5e9aea12b524772ce_add (data) {
#             geo_json_f4dfff3269f262b5e9aea12b524772ce
#                 .addData(data);
#         }
#             geo_json_f4dfff3269f262b5e9aea12b524772ce_add({&quot;bbox&quot;: [-122.55567563161817, 38.19716265716001, -122.48105486870585, 38.26275676704939], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48523239653984, 38.24732644658309, -122.48105486870585, 38.24858485457013], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48105486870585, 38.24732644658309], [-122.48523239653984, 38.24858485457013]], &quot;type&quot;

# %%
# transform_coordinate=False, noise_level="high"
gdf2a.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebca1243abc2641756ca38e92f92e3ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebca1243abc2641756ca38e92f92e3ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebca1243abc2641756ca38e92f92e3ac = L.map(
#                 &quot;map_ebca1243abc2641756ca38e92f92e3ac&quot;,
#                 {
#                     center: [38.23042738392796, -122.51895958429408],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ebca1243abc2641756ca38e92f92e3ac);
#
#
#
#
#
#             var tile_layer_82c94cb696358493a52d04a4c6e05bb2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82c94cb696358493a52d04a4c6e05bb2.addTo(map_ebca1243abc2641756ca38e92f92e3ac);
#
#
#             map_ebca1243abc2641756ca38e92f92e3ac.fitBounds(
#                 [[38.19729265578734, -122.55702559693655], [38.263562112068584, -122.4808935716516]],
#                 {}
#             );
#
#
#         function geo_json_00f8aa6f4339665e70dde28c2920b75f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_00f8aa6f4339665e70dde28c2920b75f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_00f8aa6f4339665e70dde28c2920b75f_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_00f8aa6f4339665e70dde28c2920b75f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_00f8aa6f4339665e70dde28c2920b75f_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_00f8aa6f4339665e70dde28c2920b75f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_00f8aa6f4339665e70dde28c2920b75f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_00f8aa6f4339665e70dde28c2920b75f = L.geoJson(null, {
#                 onEachFeature: geo_json_00f8aa6f4339665e70dde28c2920b75f_onEachFeature,
#
#                 style: geo_json_00f8aa6f4339665e70dde28c2920b75f_styler,
#                 pointToLayer: geo_json_00f8aa6f4339665e70dde28c2920b75f_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_00f8aa6f4339665e70dde28c2920b75f_add (data) {
#             geo_json_00f8aa6f4339665e70dde28c2920b75f
#                 .addData(data);
#         }
#             geo_json_00f8aa6f4339665e70dde28c2920b75f_add({&quot;bbox&quot;: [-122.55702559693655, 38.19729265578734, -122.4808935716516, 38.263562112068584], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48664036343281, 38.247328334374565, -122.4808935716516, 38.24937420868729], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.4808935716516, 38.247328334374565], [-122.48664036343281, 38.24937420868729]], &quot;type&quot

# %%
# transform_coordinate=True, noise_level="none"
gdf3.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8b8b6b15ceffce218444102eb53e017 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8b8b6b15ceffce218444102eb53e017&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8b8b6b15ceffce218444102eb53e017 = L.map(
#                 &quot;map_d8b8b6b15ceffce218444102eb53e017&quot;,
#                 {
#                     center: [0.019103508636253264, -0.03527685160383259],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d8b8b6b15ceffce218444102eb53e017);
#
#
#
#
#
#             var tile_layer_469fa7f5ca370c60081b8e75de650254 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_469fa7f5ca370c60081b8e75de650254.addTo(map_d8b8b6b15ceffce218444102eb53e017);
#
#
#             map_d8b8b6b15ceffce218444102eb53e017.fitBounds(
#                 [[-0.7026368078732839, -1.0], [0.7408438251457904, 0.9294462967923348]],
#                 {}
#             );
#
#
#         function geo_json_a347ed73c7fd719bd08ec0d50d566cb2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_a347ed73c7fd719bd08ec0d50d566cb2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a347ed73c7fd719bd08ec0d50d566cb2_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_a347ed73c7fd719bd08ec0d50d566cb2_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a347ed73c7fd719bd08ec0d50d566cb2_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_a347ed73c7fd719bd08ec0d50d566cb2.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a347ed73c7fd719bd08ec0d50d566cb2_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a347ed73c7fd719bd08ec0d50d566cb2 = L.geoJson(null, {
#                 onEachFeature: geo_json_a347ed73c7fd719bd08ec0d50d566cb2_onEachFeature,
#
#                 style: geo_json_a347ed73c7fd719bd08ec0d50d566cb2_styler,
#                 pointToLayer: geo_json_a347ed73c7fd719bd08ec0d50d566cb2_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_a347ed73c7fd719bd08ec0d50d566cb2_add (data) {
#             geo_json_a347ed73c7fd719bd08ec0d50d566cb2
#                 .addData(data);
#         }
#             geo_json_a347ed73c7fd719bd08ec0d50d566cb2_add({&quot;bbox&quot;: [-1.0, -0.7026368078732839, 0.9294462967923348, 0.7408438251457904], &quot;features&quot;: [{&quot;bbox&quot;: [-0.4736212647387142, 0.20218112694732754, -0.4688215053829895, 0.23428640924990915], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.4736212647387142, 0.23428640924990915], [-0.4688215053829895, 0.20218112694732754]], &quot;type&quot;: &quot;LineS

# %%
# transform_coordinate=True, noise_level="low"
gdf4.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d57d9be59683c64d0813cecfbdb3c5aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d57d9be59683c64d0813cecfbdb3c5aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d57d9be59683c64d0813cecfbdb3c5aa = L.map(
#                 &quot;map_d57d9be59683c64d0813cecfbdb3c5aa&quot;,
#                 {
#                     center: [0.01859769046119225, -0.029861103098744124],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d57d9be59683c64d0813cecfbdb3c5aa);
#
#
#
#
#
#             var tile_layer_0ad10c7c5b878981d40cf68746609b98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ad10c7c5b878981d40cf68746609b98.addTo(map_d57d9be59683c64d0813cecfbdb3c5aa);
#
#
#             map_d57d9be59683c64d0813cecfbdb3c5aa.fitBounds(
#                 [[-0.7068844359789385, -0.9960401009772408], [0.744079816901323, 0.9363178947797526]],
#                 {}
#             );
#
#
#         function geo_json_0b23ea56d00b13dae2af233a2ed74d5c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_0b23ea56d00b13dae2af233a2ed74d5c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0b23ea56d00b13dae2af233a2ed74d5c_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_0b23ea56d00b13dae2af233a2ed74d5c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0b23ea56d00b13dae2af233a2ed74d5c_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_0b23ea56d00b13dae2af233a2ed74d5c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0b23ea56d00b13dae2af233a2ed74d5c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0b23ea56d00b13dae2af233a2ed74d5c = L.geoJson(null, {
#                 onEachFeature: geo_json_0b23ea56d00b13dae2af233a2ed74d5c_onEachFeature,
#
#                 style: geo_json_0b23ea56d00b13dae2af233a2ed74d5c_styler,
#                 pointToLayer: geo_json_0b23ea56d00b13dae2af233a2ed74d5c_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_0b23ea56d00b13dae2af233a2ed74d5c_add (data) {
#             geo_json_0b23ea56d00b13dae2af233a2ed74d5c
#                 .addData(data);
#         }
#             geo_json_0b23ea56d00b13dae2af233a2ed74d5c_add({&quot;bbox&quot;: [-0.9960401009772408, -0.7068844359789385, 0.9363178947797526, 0.744079816901323], &quot;features&quot;: [{&quot;bbox&quot;: [-0.47123958830097884, 0.1992890120402088, -0.46157025195693147, 0.23309488294519712], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-0.47123958830097884, 0.23309488294519712], [-0.46157025195693147, 0.1992890120402088]],

# %%
# Un-reduced circuit
gdf5.explore(
    style_kwds={
        "color": "red",  # Line color
        "weight": 5,  # Line width
        "opacity": 0.8,  # Line transparency (optional)
    },
    legend=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb16a862a00e3017090de72a92cfc512 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb16a862a00e3017090de72a92cfc512&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb16a862a00e3017090de72a92cfc512 = L.map(
#                 &quot;map_cb16a862a00e3017090de72a92cfc512&quot;,
#                 {
#                     center: [38.229961196708544, -122.5186857132331],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_cb16a862a00e3017090de72a92cfc512);
#
#
#
#
#
#             var tile_layer_4b3e910d378e77f4a87d4f5cddb7519f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4b3e910d378e77f4a87d4f5cddb7519f.addTo(map_cb16a862a00e3017090de72a92cfc512);
#
#
#             map_cb16a862a00e3017090de72a92cfc512.fitBounds(
#                 [[38.1971361931719, -122.55649671440192], [38.262786200245195, -122.48087471206428]],
#                 {}
#             );
#
#
#         function geo_json_b98d666679dcfaad2a048baf32854080_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 5};
#             }
#         }
#         function geo_json_b98d666679dcfaad2a048baf32854080_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b98d666679dcfaad2a048baf32854080_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_b98d666679dcfaad2a048baf32854080_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b98d666679dcfaad2a048baf32854080_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b98d666679dcfaad2a048baf32854080.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b98d666679dcfaad2a048baf32854080_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b98d666679dcfaad2a048baf32854080 = L.geoJson(null, {
#                 onEachFeature: geo_json_b98d666679dcfaad2a048baf32854080_onEachFeature,
#
#                 style: geo_json_b98d666679dcfaad2a048baf32854080_styler,
#                 pointToLayer: geo_json_b98d666679dcfaad2a048baf32854080_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_b98d666679dcfaad2a048baf32854080_add (data) {
#             geo_json_b98d666679dcfaad2a048baf32854080
#                 .addData(data);
#         }
#             geo_json_b98d666679dcfaad2a048baf32854080_add({&quot;bbox&quot;: [-122.55649671440192, 38.1971361931719, -122.48087471206428, 38.262786200245195], &quot;features&quot;: [{&quot;bbox&quot;: [-122.48538151936485, 38.247201582318546, -122.48087471206428, 38.24855675680422], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.48087471206428, 38.247201582318546], [-122.48538151936485, 38.24855675680422]], &quot;type&qu
